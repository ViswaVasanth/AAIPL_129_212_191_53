# %%
from agents.question_model import QAgent
from agents.question_agent import QuestioningAgent
import json
import os
import yaml

# %%
agent = QuestioningAgent()
with open("assets/topics.json") as f: topics = json.load(f)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
gen_kwargs = {"tgps_show": True}
with open("qgen.yaml", "r") as f: gen_kwargs.update(yaml.safe_load(f))
inc_samples = QuestioningAgent.load_icl_samples("assets/topics_example.json")

# %%
question, tls, gts = agent.generate_batches(
        num_questions=20,
        topics=topics, 
        batch_size=10,
        wadvsys=True,
        wicl=True,
        inc_samples=inc_samples,
        **gen_kwargs
    )
# Out:
# STEPS:   0%|          | 0/2 [00:00<?, ?it/s]
# Generate an EXTREMELY DIFFICULT MCQ on topic: Blood Relations and Family Tree/Puzzles involving generations and family tree logic.
#
# **CRITICAL REQUIREMENTS:**
# 1.  **Topic Alignment**: The "question" must be strictly relevant to the topic: Blood Relations and Family Tree/Puzzles involving generations and family tree logic.
# 2.  **Question Quality**: The question must be EXTREMELY DIFFICULT, clear, and test deep conceptual understanding. Avoid trivial or ambiguous questions.
# 3.  **Choices (4 total)**: Generate exactly FOUR multiple-choice options, labeled "A)", "B)", "C)", and "D)".
# 4.  **Single Correct Answer**: Ensure that option A is only factually correct.
# 5.  **Plausible Distractors**: While option B, C, D are three incorrect UNIQUE choices which are highly plausible and common misconceptions related to the topic, designed to mislead someone without expert knowledge.
# ...

# %%
for q in question:
    print(q, flush=True)
# Out:
# {
#   "topic": "Puzzles involving generations and family tree logic",
#   "question": "In a family, A is the only child of B and C. D is the son of E and F, who are the parents of G. H is the daughter of I and J, who are the parents of K. L is the son of M and N, who are the parents of O. P is the daughter of Q and R, who are the parents of S. T is the son of U and V, who are the parents of W. X is the daughter of Y and Z, who are the parents of A. How is W related to O?",
#   "choices": ["A) Cousin", "B) Nephew", "C) Brother", "D) Uncle"],
#   "answer": "A",
#   "explanation": "A is the child of X and Z, making X the parent of A. W is the child of T and V, making T the parent of W. Since X and T are both children of Y and Z, they are siblings. Therefore, W and O are cousins."
# }
# {
#   "topic": "Seating Arrangements (Linear, Circular)",
# ...

# %%
question = [
  {
    "topic": "Puzzles involving generations and family tree logic",
    "question": "Pointing to a man, a woman says, 'His mother is the only daughter of my mother.' How is the woman related to the man?",
    "choices": ["A) Mother", "B) Sister", "C) Daughter", "D) Aunt"],
    "answer": "A",
    "explanation": "The 'only daughter of my mother' can only be the woman herself. The statement then becomes 'His mother is me.' Therefore, the woman is the man's mother."
  },
  {
    "topic": "Seating Arrangements (Linear, Circular)",
    "question": "Six people A, B, C, D, E, and F are sitting around a circular table facing the center. E is sitting opposite to D. C is sitting to the immediate left of A. B is sitting two places to the right of D. Who is sitting opposite to A?",
    "choices": ["A) B", "B) C", "C) F", "D) D"],
    "answer": "C",
    "explanation": "With E opposite D, and B two places to the right of D, the partial arrangement is D, _, B, E, _, _. Since C is to the immediate left of A, they must occupy the two adjacent empty seats. This places them between D and E in the order D, A, C, E. The final person, F, sits in the last spot between E and B. Therefore, F is opposite A."
  },
  {
    "topic": "Truth-teller and Liar Problems",
    "question": "On an island of knights (who always tell the truth) and knaves (who always lie), you meet two inhabitants, A and B. A says, 'B is a knight.' B says, 'The two of us are opposite types.' Which of the following is correct?",
    "choices": ["A) A is a knight, B is a knight", "B) A is a knave, B is a knight", "C) A is a knight, B is a knave", "D) A is a knave, B is a knave"],
    "answer": "D",
    "explanation": "If A were a knight, his statement would be true, making B a knight. But a knight B would truthfully state they are opposite types, which is a contradiction. Therefore, A must be a knave. As a knave, A's statement 'B is a knight' is a lie, so B is also a knave. B's statement that they are opposite types is also a lie (meaning they are the same type), which is consistent with them both being knaves."
  },
  {
    "topic": "Puzzles involving generations and family tree logic",
    "question": "Priya is Ramesh's sister, and Ravi is Priya's son. Sunita's mother is the sister of Ramesh's father. How is Ravi related to Sunita?",
    "choices": ["A) Brother", "B) First cousin", "C) Second cousin", "D) First cousin, once removed"],
    "answer": "D",
    "explanation": "Ramesh's father and Sunita's mother are siblings. This makes Ramesh and Sunita first cousins. Since Priya is Ramesh's sister, Priya and Sunita are also first cousins. Ravi is the son of Priya. The child of one's first cousin is one's first cousin, once removed. Therefore, Ravi is Sunita's first cousin, once removed."
  },
  {
    "topic": "Seating Arrangements (Linear, Circular)",
    "question": "Eight people A, B, C, D, E, F, G, and H sit in a circle facing the center. E is seated directly opposite A. C is two seats to the right of E. B is an immediate neighbor of both G and A. D sits second to the left of G. Who is seated opposite to H?",
    "choices": ["A) G", "B) F", "C) B", "D) D"],
    "answer": "A",
    "explanation": "Place E and A opposite each other. C is two to the right of E. The order G-B-A is fixed. D is second to the left of G. Following these placements step-by-step, the final clockwise arrangement is A, B, G, F, E, H, C, D. In this arrangement, G is opposite H."
  },
  {
    "topic": "Truth-teller and Liar Problems",
    "question": "Three inhabitants, A, B, and C, are on an island of knights (always tell truth) and knaves (always lie). A says, 'We are all knaves.' B says, 'Exactly one of us is a knight.' Who is the knight?",
    "choices": ["A) A", "B) B", "C) C", "D) No one is a knight"],
    "answer": "C",
    "explanation": "A cannot be a knight, because a knight wouldn't claim to be a knave. So A is a knave. This makes his statement 'We are all knaves' false, so there must be at least one knight. If B were the knight, his statement 'Exactly one of us is a knight' would be true. This would mean C is a knave. This scenario works (A=knave, B=knight, C=knave). However, if B is a knave, his statement is false. The only way for 'Exactly one of us is a knight' to be false is if there are 0, 2, or 3 knights. We know there's at least one. If B is a knave, and we need the statement to be false, then C must be the knight, which makes the number of knights 2 (A and B are knaves, C is a knight). Let's re-evaluate. If A is a knave, his statement is false, so not all are knaves. Consider B's statement. If B is a knight, his statement is true, so there is only one knight (himself). This makes C a knave. This is a consistent solution: A=Knave, B=Knight, C=Knave. Let's re-read the puzzle. Ah, my deduction was slightly off. Let's restart. 1) A cannot be a knight, because a knight would not lie and say he is a knave. So A is a knave. 2) Since A is a knave, his statement 'We are all knaves' is a lie. This means there is at least one knight. 3) Now consider B's statement: 'Exactly one of us is a knight.' If B is telling the truth (is a knight), then this is a consistent outcome. A is a knave, B is a knight, so C must be a knave. 4) If B is lying (is a knave), then his statement is false, meaning there are 0, 2, or 3 knights. We know it's not 0 and it can't be 3 (since A and B are knaves). So there must be 2 knights. This would mean C is a knight. But this leads to a contradiction because B would be a knave, and his lie would mean there are two knights (himself and C), but we established B is a knave. So the only logical solution is that B is a knight and C is a knave. The provided answer C is therefore incorrect based on this logic. A better question would be needed. Let's correct the entire entry. 'Three inhabitants A, B, C are on an island. A says, 'B is a knave'. B says, 'C is a knave'. C says, 'A is a knave'. If there is exactly one knight, who is it?' Let's solve this one. Assume A is the knight -> B is a knave (True). B's statement 'C is a knave' is a lie -> C is a knight. This contradicts 'exactly one knight'. Assume B is the knight -> B's statement 'C is a knave' is true -> C is a knave. C's statement 'A is a knave' is a lie -> A is a knight. This contradicts 'exactly one knight'. Assume C is the knight -> C's statement 'A is a knave' is true -> A is a knave. A's statement 'B is a knave' is a lie -> B is a knight. This contradicts 'exactly one knight'. The premise of this new puzzle is also flawed. A good, solvable problem is needed."
  },
  {
    "topic": "Truth-teller and Liar Problems",
    "question": "You meet three islanders: A, B, and C. A says, 'B and C are of the same type.' You ask C, 'Are A and B of the same type?'. What does C answer?",
    "choices": ["A) Yes", "B) No", "C) Cannot be determined", "D) 'I am a knave'"],
    "answer": "A",
    "explanation": "Case 1: C is a Knight. A and B must be of opposite types for C to answer 'No', or the same type to answer 'Yes'. If A is a Knight, B must also be a knight (from A's statement). Then C would see A and B are the same and say 'Yes'. If A is a Knave, B must be a Knight (A's statement is a lie). Then C would see they are different and say 'No'. Case 2: C is a Knave. C will lie. If A is a Knight, B is a Knight. C sees they are the same, so C must lie and say 'No'. If A is a Knave, B is a Knight. C sees they are different, so C must lie and say 'Yes'. This is becoming too complex. Let's simplify. A Knight will always see a Knight and Knave as different. A Knave will always see a Knight and Knave as the same (because they would lie about it). Let's go back to the core logic. Consider C. If C is a knight, C will truthfully report if A and B are the same or different. If C is a knave, C will lie. Now consider A. If A is a knight, B and C are the same. So they are both knights or both knaves. C cannot be a knight if A is (contradiction). So A, B, C are all knights (contradiction) or A is a knight, B and C are knaves. If A is a knave, B and C are different types. Let's analyze the possibilities. If C is a Knight, whatever C says is true. If C is a Knave, whatever C says is false. In any possible scenario, the islander C will always answer 'Yes'. If C is a Knight, A and B must be of the same type for the logic to be consistent. If C is a Knave, A and B must be of different types, but C would lie and say they are the same."
  }
]

# %%
question[0]
# Out:
# {'topic': 'Puzzles involving generations and family tree logic',
#  'question': "Pointing to a man, a woman says, 'His mother is the only daughter of my mother.' How is the woman related to the man?",
#  'choices': ['A) Mother', 'B) Sister', 'C) Daughter', 'D) Aunt'],
#  'answer': 'A',
#  'explanation': "The 'only daughter of my mother' can only be the woman herself. The statement then becomes 'His mother is me.' Therefore, the woman is the man's mother."}

# %%
from agents.answer_agent import AnsweringAgent
import json
import os
import yaml

# %%
a_agent = AnsweringAgent(False)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
gen_kwargs = {"tgps_show": True}
with open("agen.yaml", "r") as f: gen_kwargs.update(yaml.safe_load(f))
answer, tls, gts = a_agent.answer_batches(
    questions=question,#[json.loads(q) for q in question],
    batch_size=5,
    **gen_kwargs
)
# Out:
# STEPS: : 3batch [00:08,  2.79s/batch]

# %%
qns = question#[json.loads(q) for q in question]
ans = [json.loads(a) for a in answer]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[25], line 2
#       1 qns = question#[json.loads(q) for q in question]
# ----> 2 ans = [json.loads(a) for a in answer]
#
# File /usr/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     333 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
count=0
for q, a in zip(qns, answer):
    try:
        a = json.loads(a)
        if q['answer'] == a['answer']:
            count+=1
    except Exception as e:
        print(a)
print(count/len(qns))
# Out:
# {
#     "answer": "C",
#     "reasoning": "If A is a knight (truth-teller), then B must be a knight. But B says they are opposite types, which would be a lie if B is a knight. This contradiction means A cannot be a knight. If A is a knave (liar), then B is not a knight, so B is a knave. B's statement 'we are opposite types' would then be a lie, which is consistent. Thus, A is a knight and B is a knave."
# 0.14285714285714285

# %%
count
# Out:
# 1

# %%
len(qns)
# Out:
# 7
